# %% [markdown]
# ## Introduction
# This notebook tests the model tracing algorithm implemented in [idlmav_tracing.py](../idlmav_tracing.py). For notebooks containing development notes and exploratory code for this algorithm, see [07_explore_tracing.ipynb](./07_explore_tracing.ipynb) and [09_explore_fx_interpreter](./09_explore_fx_interpreter.ipynb)

# %% [markdown]
# ## Imports

# %%
import sys
import os
import importlib
workspace_path = os.path.abspath(os.path.join(os.path.abspath(''), '..'))
sys.path.append(workspace_path)

from idlmav_tracing import MavTracer

# %%
from typing import Dict, Tuple
import numpy as np
import torch
from torch import nn, Tensor
import torch.nn.functional as F
import torchvision
import timm

import torchinfo

from miniai.init import clean_mem
from miniai.resnet import ResBlock, act_gr, conv

# %% [markdown]
# ### To reload updated imports

# %%
def reload_imports():
    importlib.reload(sys.modules['idlmav_tracing'])
    global MavTracer
    from idlmav_tracing import MavTracer

# %% [markdown]
# ## Models

# %% [markdown]
# ### Hand-written CNN (for MNIST)
# * Found [here](https://github.com/pytorch/examples/blob/main/mnist/main.py)
# * Modified for experimental purposes, e.g. breaking the forward pass

# %%
class MnistCnn(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output

def get_model_cnn_mnist():
    return MnistCnn()

def get_model_cnn_mnist_broken():
    model = MnistCnn()
    model.fc1 = nn.Linear(9216, 120)
    return model

# %% [markdown]
# ### ResNet18 (from TorchVision)

# %%
def get_model_tv_resnet18():
    return torchvision.models.resnet.resnet18()

# %% [markdown]
# ### ResNet18 (from timm)

# %%
def get_model_timm_resnet18():
    return timm.create_model('resnet18', in_chans=3, num_classes=10)

# %% [markdown]
# ### ResNet (from miniai)

# %%
def get_model_miniai_resnet(act=nn.ReLU, nfs=(16,32,64,128,256), norm=nn.BatchNorm2d):
    class GlobalAvgPool(nn.Module):
        def forward(self, x:Tensor): return x.mean((-2,-1))
    layers = [conv(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [GlobalAvgPool(), nn.Linear(256, 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %% [markdown]
# ### Autoencoder (from miniai)

# %%
def get_model_miniai_autoenc(act=act_gr, nfs=(32,64,128,256,512), norm=nn.BatchNorm2d, drop=0.1):
    def up_block(ni, nf, ks=3, act=act_gr, norm=None):
        return nn.Sequential(nn.UpsamplingNearest2d(scale_factor=2),
                            ResBlock(ni, nf, ks=ks, act=act, norm=norm))
    layers = [ResBlock(3, nfs[0], ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [up_block(nfs[i], nfs[i-1], act=act, norm=norm) for i in range(len(nfs)-1,0,-1)]
    layers += [ResBlock(nfs[0], 3, act=nn.Identity, norm=norm)]
    return nn.Sequential(*layers)

# %% [markdown]
# ### UNet (from miniai)

# %%
def up_block(ni, nf, ks=3, act=act_gr, norm=None):
    return nn.Sequential(nn.UpsamplingNearest2d(scale_factor=2),
                        ResBlock(ni, nf, ks=ks, act=act, norm=norm))

class TinyUnet(nn.Module):
    def __init__(self, act=act_gr, nfs=(32,64,128,256,512), norm=nn.BatchNorm2d):
        super().__init__()
        self.start = ResBlock(3, nfs[0], stride=1, act=act, norm=norm)
        self.dn = nn.ModuleList([ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2)
                                 for i in range(len(nfs)-1)])
        self.up = nn.ModuleList([up_block(nfs[i], nfs[i-1], act=act, norm=norm)
                                 for i in range(len(nfs)-1,0,-1)])
        self.up += [ResBlock(nfs[0], 3, act=act, norm=norm)]
        self.end = ResBlock(3, 3, act=nn.Identity, norm=norm)

    def forward(self, x):
        layers = []
        layers.append(x)
        x = self.start(x)
        for l in self.dn:
            layers.append(x)
            x = l(x)
        n = len(layers)
        for i,l in enumerate(self.up):
            if i!=0: x += layers[n-i]
            x = l(x)
        return self.end(x+layers[0])
    
def get_model_miniai_unet():
    return TinyUnet()

# %% [markdown]
# ### Model preparation helpers

# %%
def get_model_and_input_size(name, device):
    match name:
        case 'cnn_mnist':
            return get_model_cnn_mnist().to(device), (16,1,28,28)
        case 'cnn_mnist_broken':
            return get_model_cnn_mnist_broken().to(device), (16,1,28,28)
        case 'tv_resnet18':
            return get_model_tv_resnet18().to(device), (16,3,160,160)
        case 'timm_resnet18':
            return get_model_timm_resnet18().to(device), (16,3,160,160)
        case 'miniai_resnet':
            return get_model_miniai_resnet().to(device), (16,1,28,28)
        case 'miniai_autoenc':
            return get_model_miniai_autoenc().to(device), (16,3,160,160)
        case 'miniai_unet':
            return get_model_miniai_unet().to(device), (16,3,160,160)
        case _:
            return None
        
def get_models_and_input_tensors(model_names, device):
    """
    This function returns 3 dictionaries, all indexed by the model name:
    * A dictionary of `nn.Module` models
    * A dictionary of tuples: the input sizes for each model
    * A dictionary of tensors that can be passed to each model
    """
    clean_mem()
    models: Dict[str, nn.Module] = {}
    input_sizes: Dict[str, Tuple[int]] = {}
    inputs: Dict[str, Tensor] = {}
    for name in model_names:
        model, input_size = get_model_and_input_size(name, device)
        x = torch.randn(input_size).to(device)
        models[name] = model
        input_sizes[name] = input_size
        inputs[name] = x
    return models, input_sizes, inputs

def remove_all_hooks(model:nn.Module):
    # Iterate through all submodules
    for module in model.modules():
        # Clear forward hooks
        if hasattr(module, '_forward_hooks'):
            module._forward_hooks.clear()

        # Clear backward hooks
        if hasattr(module, '_backward_hooks'):
            module._backward_hooks.clear()

        # Clear pre-forward hooks if any (less common)
        if hasattr(module, '_forward_pre_hooks'):
            module._forward_pre_hooks.clear()

# %%
device = 'cpu'  # ['cpu','cuda']
model_names = ['cnn_mnist', 'cnn_mnist_broken', 'tv_resnet18', 'timm_resnet18', 'miniai_resnet', 'miniai_autoenc', 'miniai_unet']
models, input_sizes, inputs = get_models_and_input_tensors(model_names, device)

# %% [markdown]
# ## Tests

# %%
def run_algorithm(model_name):
    tracer = MavTracer(models[model_name], inputs[model_name], device=device)
    print(tracer.summary())

def run_comparison(model_name):
    torchinfo.summary(models[model_name], input_size=input_sizes[model_name], verbose=1, depth=8, 
                      col_names=["output_size","num_params","mult_adds","input_size","kernel_size"]);

# %% [markdown]
# ### Hand-written CNN (for MNIST)

# %%
run_algorithm('cnn_mnist')
# Out:
# name         operation      activations         params      flops
# -----------  -------------  ----------------  --------  ---------
# x            input          (16, 1, 28, 28)          0          0
# conv1        nn.Conv2d      (16, 32, 26, 26)       320    6230016
# relu         relu()         (16, 32, 26, 26)         0          0
# conv2        nn.Conv2d      (16, 64, 24, 24)     18496  339738624
# relu_1       relu()         (16, 64, 24, 24)         0          0
# max_pool2d   max_pool2d()   (16, 64, 12, 12)         0          0
# dropout1     nn.Dropout     (16, 64, 12, 12)         0          0
# flatten      flatten()      (16, 9216)               0          0
# fc1          nn.Linear      (16, 128)          1179776   37748736
# relu_2       relu()         (16, 128)                0          0
# dropout2     nn.Dropout     (16, 128)                0          0
# fc2          nn.Linear      (16, 10)              1290      40960
# log_softmax  log_softmax()  (16, 10)                 0          0
# output       output         (16, 10)                 0          0

# %%
run_comparison('cnn_mnist')
# Out:
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #                   Mult-Adds                 Input Shape               Kernel Shape
# =====================================================================================================================================================================
# MnistCnn                                 [16, 10]                  --                        --                        [16, 1, 28, 28]           --
# ├─Conv2d: 1-1                            [16, 32, 26, 26]          320                       3,461,120                 [16, 1, 28, 28]           [3, 3]
# ├─Conv2d: 1-2                            [16, 64, 24, 24]          18,496                    170,459,136               [16, 32, 26, 26]          [3, 3]
# ├─Dropout: 1-3                           [16, 64, 12, 12]          --                        --                        [16, 64, 12, 12]          --
# ├─Linear: 1-4                            [16, 128]                 1,179,776                 18,876,416                [16, 9216]                --
# ├─Dropout: 1-5                           [16, 128]                 --                        --                        [16, 128]                 --
# ├─Linear: 1-6                            [16, 10]                  1,290                     20,640                    [16, 128]                 --
# =====================================================================================================================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# Total mult-adds (M): 192.82
# =====================================================================================================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 7.51
# Params size (MB): 4.80
# Estimated Total Size (MB): 12.35
# =====================================================================================================================================================================

# %% [markdown]
# ### Broken model

# %%
run_algorithm('cnn_mnist_broken')
# Out:
# name         operation      activations         params      flops
# -----------  -------------  ----------------  --------  ---------
# x            input          (16, 1, 28, 28)          0          0
# conv1        nn.Conv2d      (16, 32, 26, 26)       320    6230016
# relu         relu()         (16, 32, 26, 26)         0          0
# conv2        nn.Conv2d      (16, 64, 24, 24)     18496  339738624
# relu_1       relu()         (16, 64, 24, 24)         0          0
# max_pool2d   max_pool2d()   (16, 64, 12, 12)         0          0
# dropout1     nn.Dropout     (16, 64, 12, 12)         0          0
# flatten      flatten()      (16, 9216)               0          0
# fc1          nn.Linear      (16, 120)          1106040   35389440
# relu_2       relu()         (16, 120)                0          0
# dropout2     nn.Dropout     (16, 120)                0          0
# fc2          nn.Linear      (0,)                  1290          0
# log_softmax  log_softmax()  (0,)                     0          0
# output       output         (0,)                     0          0
# /home/dev/ai/idlmav/idlmav_tracing.py:117: UserWarning: Forward pass failed. Last successful node: "dropout2:Dropout". Possible error node: "fc2:Linear".: mat1 and mat2 shapes cannot be multiplied (16x120 and 128x10)
#
# While executing %fc2 : [num_users=1] = call_module[target=fc2](args = (%dropout2,), kwargs = {})
# Original traceback:
# None
#   warnings.warn(f'{msg}: {e}')

# %%
try:
    run_comparison('cnn_mnist_broken')
except Exception as e:
    print(f'Comparison failed: {e}')
# Out:
# Comparison failed: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: [Conv2d: 1, Conv2d: 1, Dropout: 1, Linear: 1, Dropout: 1]

# %% [markdown]
# ### ResNet18 (from TorchVision)

# %%
run_algorithm('tv_resnet18')
# Out:
# name                   operation             activations          params       flops
# ---------------------  --------------------  -----------------  --------  ----------
# x                      input                 (16, 3, 160, 160)         0           0
# conv1                  nn.Conv2d             (16, 64, 80, 80)       9408  1926758400
# bn1                    nn.BatchNorm2d        (16, 64, 80, 80)        128    13107200
# relu                   nn.ReLU               (16, 64, 80, 80)          0           0
# maxpool                nn.MaxPool2d          (16, 64, 40, 40)          0           0
# layer1_0_conv1         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_0_bn1           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# layer1_0_relu          nn.ReLU               (16, 64, 40, 40)          0           0
# layer1_0_conv2         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_0_bn2           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# add                    add()                 (16, 64, 40, 40)          0           0
# layer1_0_relu_1        nn.ReLU               (16, 64, 40, 40)          0           0
# layer1_1_conv1         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_1_bn1           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# layer1_1_relu          nn.ReLU               (16, 64, 40, 40)          0           0
# layer1_1_conv2         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_1_bn2           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# add_1                  add()                 (16, 64, 40, 40)          0           0
# layer1_1_relu_1        nn.ReLU               (16, 64, 40, 40)          0           0
# layer2_0_conv1         nn.Conv2d             (16, 128, 20, 20)     73728   943718400
# layer2_0_bn1           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# layer2_0_relu          nn.ReLU               (16, 128, 20, 20)         0           0
# layer2_0_conv2         nn.Conv2d             (16, 128, 20, 20)    147456  1887436800
# layer2_0_bn2           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# layer2_0_downsample_0  nn.Conv2d             (16, 128, 20, 20)      8192   104857600
# layer2_0_downsample_1  nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# add_2                  add()                 (16, 128, 20, 20)         0           0
# layer2_0_relu_1        nn.ReLU               (16, 128, 20, 20)         0           0
# layer2_1_conv1         nn.Conv2d             (16, 128, 20, 20)    147456  1887436800
# layer2_1_bn1           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# layer2_1_relu          nn.ReLU               (16, 128, 20, 20)         0           0
# layer2_1_conv2         nn.Conv2d             (16, 128, 20, 20)    147456  1887436800
# layer2_1_bn2           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# add_3                  add()                 (16, 128, 20, 20)         0           0
# layer2_1_relu_1        nn.ReLU               (16, 128, 20, 20)         0           0
# layer3_0_conv1         nn.Conv2d             (16, 256, 10, 10)    294912   943718400
# layer3_0_bn1           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# layer3_0_relu          nn.ReLU               (16, 256, 10, 10)         0           0
# layer3_0_conv2         nn.Conv2d             (16, 256, 10, 10)    589824  1887436800
# layer3_0_bn2           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# layer3_0_downsample_0  nn.Conv2d             (16, 256, 10, 10)     32768   104857600
# layer3_0_downsample_1  nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# add_4                  add()                 (16, 256, 10, 10)         0           0
# layer3_0_relu_1        nn.ReLU               (16, 256, 10, 10)         0           0
# layer3_1_conv1         nn.Conv2d             (16, 256, 10, 10)    589824  1887436800
# layer3_1_bn1           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# layer3_1_relu          nn.ReLU               (16, 256, 10, 10)         0           0
# layer3_1_conv2         nn.Conv2d             (16, 256, 10, 10)    589824  1887436800
# layer3_1_bn2           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# add_5                  add()                 (16, 256, 10, 10)         0           0
# layer3_1_relu_1        nn.ReLU               (16, 256, 10, 10)         0           0
# layer4_0_conv1         nn.Conv2d             (16, 512, 5, 5)     1179648   943718400
# layer4_0_bn1           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# layer4_0_relu          nn.ReLU               (16, 512, 5, 5)           0           0
# layer4_0_conv2         nn.Conv2d             (16, 512, 5, 5)     2359296  1887436800
# layer4_0_bn2           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# layer4_0_downsample_0  nn.Conv2d             (16, 512, 5, 5)      131072   104857600
# layer4_0_downsample_1  nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# add_6                  add()                 (16, 512, 5, 5)           0           0
# layer4_0_relu_1        nn.ReLU               (16, 512, 5, 5)           0           0
# layer4_1_conv1         nn.Conv2d             (16, 512, 5, 5)     2359296  1887436800
# layer4_1_bn1           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# layer4_1_relu          nn.ReLU               (16, 512, 5, 5)           0           0
# layer4_1_conv2         nn.Conv2d             (16, 512, 5, 5)     2359296  1887436800
# layer4_1_bn2           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# add_7                  add()                 (16, 512, 5, 5)           0           0
# layer4_1_relu_1        nn.ReLU               (16, 512, 5, 5)           0           0
# avgpool                nn.AdaptiveAvgPool2d  (16, 512, 1, 1)           0       16384
# flatten                flatten()             (16, 512)                 0           0
# fc                     nn.Linear             (16, 1000)           513000    16384000
# output                 output                (16, 1000)                0           0

# %%
run_comparison('tv_resnet18')
# Out:
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #                   Mult-Adds                 Input Shape               Kernel Shape
# =====================================================================================================================================================================
# ResNet                                   [16, 1000]                --                        --                        [16, 3, 160, 160]         --
# ├─Conv2d: 1-1                            [16, 64, 80, 80]          9,408                     963,379,200               [16, 3, 160, 160]         [7, 7]
# ├─BatchNorm2d: 1-2                       [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# ├─ReLU: 1-3                              [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# ├─MaxPool2d: 1-4                         [16, 64, 40, 40]          --                        --                        [16, 64, 80, 80]          3
# ├─Sequential: 1-5                        [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    └─BasicBlock: 2-1                   [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-1                  [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-2             [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-3                    [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-4                  [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-5             [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-6                    [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    └─BasicBlock: 2-2                   [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-7                  [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-8             [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-9                    [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-10                 [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-11            [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-12                   [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# ├─Sequential: 1-6                        [16, 128, 20, 20]         --                        --                        [16, 64, 40, 40]          --
# │    └─BasicBlock: 2-3                   [16, 128, 20, 20]         --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-13                 [16, 128, 20, 20]         73,728                    471,859,200               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-14            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-15                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-16                 [16, 128, 20, 20]         147,456                   943,718,400               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-17            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─Sequential: 3-18             [16, 128, 20, 20]         --                        --                        [16, 64, 40, 40]          --
# │    │    │    └─Conv2d: 4-1             [16, 128, 20, 20]         8,192                     52,428,800                [16, 64, 40, 40]          [1, 1]
# │    │    │    └─BatchNorm2d: 4-2        [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-19                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    └─BasicBlock: 2-4                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-20                 [16, 128, 20, 20]         147,456                   943,718,400               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-21            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-22                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-23                 [16, 128, 20, 20]         147,456                   943,718,400               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-24            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-25                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# ├─Sequential: 1-7                        [16, 256, 10, 10]         --                        --                        [16, 128, 20, 20]         --
# │    └─BasicBlock: 2-5                   [16, 256, 10, 10]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-26                 [16, 256, 10, 10]         294,912                   471,859,200               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-27            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-28                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-29                 [16, 256, 10, 10]         589,824                   943,718,400               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-30            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─Sequential: 3-31             [16, 256, 10, 10]         --                        --                        [16, 128, 20, 20]         --
# │    │    │    └─Conv2d: 4-3             [16, 256, 10, 10]         32,768                    52,428,800                [16, 128, 20, 20]         [1, 1]
# │    │    │    └─BatchNorm2d: 4-4        [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-32                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    └─BasicBlock: 2-6                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-33                 [16, 256, 10, 10]         589,824                   943,718,400               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-34            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-35                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-36                 [16, 256, 10, 10]         589,824                   943,718,400               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-37            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-38                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# ├─Sequential: 1-8                        [16, 512, 5, 5]           --                        --                        [16, 256, 10, 10]         --
# │    └─BasicBlock: 2-7                   [16, 512, 5, 5]           --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-39                 [16, 512, 5, 5]           1,179,648                 471,859,200               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-40            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-41                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Conv2d: 3-42                 [16, 512, 5, 5]           2,359,296                 943,718,400               [16, 512, 5, 5]           [3, 3]
# │    │    └─BatchNorm2d: 3-43            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─Sequential: 3-44             [16, 512, 5, 5]           --                        --                        [16, 256, 10, 10]         --
# │    │    │    └─Conv2d: 4-5             [16, 512, 5, 5]           131,072                   52,428,800                [16, 256, 10, 10]         [1, 1]
# │    │    │    └─BatchNorm2d: 4-6        [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-45                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    └─BasicBlock: 2-8                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Conv2d: 3-46                 [16, 512, 5, 5]           2,359,296                 943,718,400               [16, 512, 5, 5]           [3, 3]
# │    │    └─BatchNorm2d: 3-47            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-48                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Conv2d: 3-49                 [16, 512, 5, 5]           2,359,296                 943,718,400               [16, 512, 5, 5]           [3, 3]
# │    │    └─BatchNorm2d: 3-50            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-51                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# ├─AdaptiveAvgPool2d: 1-9                 [16, 512, 1, 1]           --                        --                        [16, 512, 5, 5]           --
# ├─Linear: 1-10                           [16, 1000]                513,000                   8,208,000                 [16, 512]                 --
# =====================================================================================================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (G): 14.81
# =====================================================================================================================================================================
# Input size (MB): 4.92
# Forward/backward pass size (MB): 324.53
# Params size (MB): 46.76
# Estimated Total Size (MB): 376.20
# =====================================================================================================================================================================

# %% [markdown]
# ### ResNet18 (from timm)

# %%
run_algorithm('timm_resnet18')
# Out:
# name                   operation             activations          params       flops
# ---------------------  --------------------  -----------------  --------  ----------
# x                      input                 (16, 3, 160, 160)         0           0
# conv1                  nn.Conv2d             (16, 64, 80, 80)       9408  1926758400
# bn1                    nn.BatchNorm2d        (16, 64, 80, 80)        128    13107200
# act1                   nn.ReLU               (16, 64, 80, 80)          0           0
# maxpool                nn.MaxPool2d          (16, 64, 40, 40)          0           0
# layer1_0_conv1         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_0_bn1           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# layer1_0_drop_block    nn.Identity           (16, 64, 40, 40)          0           0
# layer1_0_act1          nn.ReLU               (16, 64, 40, 40)          0           0
# layer1_0_aa            nn.Identity           (16, 64, 40, 40)          0           0
# layer1_0_conv2         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_0_bn2           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# add                    add()                 (16, 64, 40, 40)          0           0
# layer1_0_act2          nn.ReLU               (16, 64, 40, 40)          0           0
# layer1_1_conv1         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_1_bn1           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# layer1_1_drop_block    nn.Identity           (16, 64, 40, 40)          0           0
# layer1_1_act1          nn.ReLU               (16, 64, 40, 40)          0           0
# layer1_1_aa            nn.Identity           (16, 64, 40, 40)          0           0
# layer1_1_conv2         nn.Conv2d             (16, 64, 40, 40)      36864  1887436800
# layer1_1_bn2           nn.BatchNorm2d        (16, 64, 40, 40)        128     3276800
# add_1                  add()                 (16, 64, 40, 40)          0           0
# layer1_1_act2          nn.ReLU               (16, 64, 40, 40)          0           0
# layer2_0_conv1         nn.Conv2d             (16, 128, 20, 20)     73728   943718400
# layer2_0_bn1           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# layer2_0_drop_block    nn.Identity           (16, 128, 20, 20)         0           0
# layer2_0_act1          nn.ReLU               (16, 128, 20, 20)         0           0
# layer2_0_aa            nn.Identity           (16, 128, 20, 20)         0           0
# layer2_0_conv2         nn.Conv2d             (16, 128, 20, 20)    147456  1887436800
# layer2_0_bn2           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# layer2_0_downsample_0  nn.Conv2d             (16, 128, 20, 20)      8192   104857600
# layer2_0_downsample_1  nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# add_2                  add()                 (16, 128, 20, 20)         0           0
# layer2_0_act2          nn.ReLU               (16, 128, 20, 20)         0           0
# layer2_1_conv1         nn.Conv2d             (16, 128, 20, 20)    147456  1887436800
# layer2_1_bn1           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# layer2_1_drop_block    nn.Identity           (16, 128, 20, 20)         0           0
# layer2_1_act1          nn.ReLU               (16, 128, 20, 20)         0           0
# layer2_1_aa            nn.Identity           (16, 128, 20, 20)         0           0
# layer2_1_conv2         nn.Conv2d             (16, 128, 20, 20)    147456  1887436800
# layer2_1_bn2           nn.BatchNorm2d        (16, 128, 20, 20)       256     1638400
# add_3                  add()                 (16, 128, 20, 20)         0           0
# layer2_1_act2          nn.ReLU               (16, 128, 20, 20)         0           0
# layer3_0_conv1         nn.Conv2d             (16, 256, 10, 10)    294912   943718400
# layer3_0_bn1           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# layer3_0_drop_block    nn.Identity           (16, 256, 10, 10)         0           0
# layer3_0_act1          nn.ReLU               (16, 256, 10, 10)         0           0
# layer3_0_aa            nn.Identity           (16, 256, 10, 10)         0           0
# layer3_0_conv2         nn.Conv2d             (16, 256, 10, 10)    589824  1887436800
# layer3_0_bn2           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# layer3_0_downsample_0  nn.Conv2d             (16, 256, 10, 10)     32768   104857600
# layer3_0_downsample_1  nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# add_4                  add()                 (16, 256, 10, 10)         0           0
# layer3_0_act2          nn.ReLU               (16, 256, 10, 10)         0           0
# layer3_1_conv1         nn.Conv2d             (16, 256, 10, 10)    589824  1887436800
# layer3_1_bn1           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# layer3_1_drop_block    nn.Identity           (16, 256, 10, 10)         0           0
# layer3_1_act1          nn.ReLU               (16, 256, 10, 10)         0           0
# layer3_1_aa            nn.Identity           (16, 256, 10, 10)         0           0
# layer3_1_conv2         nn.Conv2d             (16, 256, 10, 10)    589824  1887436800
# layer3_1_bn2           nn.BatchNorm2d        (16, 256, 10, 10)       512      819200
# add_5                  add()                 (16, 256, 10, 10)         0           0
# layer3_1_act2          nn.ReLU               (16, 256, 10, 10)         0           0
# layer4_0_conv1         nn.Conv2d             (16, 512, 5, 5)     1179648   943718400
# layer4_0_bn1           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# layer4_0_drop_block    nn.Identity           (16, 512, 5, 5)           0           0
# layer4_0_act1          nn.ReLU               (16, 512, 5, 5)           0           0
# layer4_0_aa            nn.Identity           (16, 512, 5, 5)           0           0
# layer4_0_conv2         nn.Conv2d             (16, 512, 5, 5)     2359296  1887436800
# layer4_0_bn2           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# layer4_0_downsample_0  nn.Conv2d             (16, 512, 5, 5)      131072   104857600
# layer4_0_downsample_1  nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# add_6                  add()                 (16, 512, 5, 5)           0           0
# layer4_0_act2          nn.ReLU               (16, 512, 5, 5)           0           0
# layer4_1_conv1         nn.Conv2d             (16, 512, 5, 5)     2359296  1887436800
# layer4_1_bn1           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# layer4_1_drop_block    nn.Identity           (16, 512, 5, 5)           0           0
# layer4_1_act1          nn.ReLU               (16, 512, 5, 5)           0           0
# layer4_1_aa            nn.Identity           (16, 512, 5, 5)           0           0
# layer4_1_conv2         nn.Conv2d             (16, 512, 5, 5)     2359296  1887436800
# layer4_1_bn2           nn.BatchNorm2d        (16, 512, 5, 5)        1024      409600
# add_7                  add()                 (16, 512, 5, 5)           0           0
# layer4_1_act2          nn.ReLU               (16, 512, 5, 5)           0           0
# global_pool_pool       nn.AdaptiveAvgPool2d  (16, 512, 1, 1)           0       16384
# global_pool_flatten    nn.Flatten            (16, 512)                 0           0
# fc                     nn.Linear             (16, 10)               5130      163840
# output                 output                (16, 10)                  0           0

# %%
run_comparison('timm_resnet18')
# Out:
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #                   Mult-Adds                 Input Shape               Kernel Shape
# =====================================================================================================================================================================
# ResNet                                   [16, 10]                  --                        --                        [16, 3, 160, 160]         --
# ├─Conv2d: 1-1                            [16, 64, 80, 80]          9,408                     963,379,200               [16, 3, 160, 160]         [7, 7]
# ├─BatchNorm2d: 1-2                       [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# ├─ReLU: 1-3                              [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# ├─MaxPool2d: 1-4                         [16, 64, 40, 40]          --                        --                        [16, 64, 80, 80]          3
# ├─Sequential: 1-5                        [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    └─BasicBlock: 2-1                   [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-1                  [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-2             [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─Identity: 3-3                [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-4                    [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Identity: 3-5                [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-6                  [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-7             [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-8                    [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    └─BasicBlock: 2-2                   [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-9                  [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-10            [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─Identity: 3-11               [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-12                   [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Identity: 3-13               [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-14                 [16, 64, 40, 40]          36,864                    943,718,400               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-15            [16, 64, 40, 40]          128                       2,048                     [16, 64, 40, 40]          --
# │    │    └─ReLU: 3-16                   [16, 64, 40, 40]          --                        --                        [16, 64, 40, 40]          --
# ├─Sequential: 1-6                        [16, 128, 20, 20]         --                        --                        [16, 64, 40, 40]          --
# │    └─BasicBlock: 2-3                   [16, 128, 20, 20]         --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-17                 [16, 128, 20, 20]         73,728                    471,859,200               [16, 64, 40, 40]          [3, 3]
# │    │    └─BatchNorm2d: 3-18            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─Identity: 3-19               [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-20                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Identity: 3-21               [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-22                 [16, 128, 20, 20]         147,456                   943,718,400               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-23            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─Sequential: 3-24             [16, 128, 20, 20]         --                        --                        [16, 64, 40, 40]          --
# │    │    │    └─Conv2d: 4-1             [16, 128, 20, 20]         8,192                     52,428,800                [16, 64, 40, 40]          [1, 1]
# │    │    │    └─BatchNorm2d: 4-2        [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-25                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    └─BasicBlock: 2-4                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-26                 [16, 128, 20, 20]         147,456                   943,718,400               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-27            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─Identity: 3-28               [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-29                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Identity: 3-30               [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-31                 [16, 128, 20, 20]         147,456                   943,718,400               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-32            [16, 128, 20, 20]         256                       4,096                     [16, 128, 20, 20]         --
# │    │    └─ReLU: 3-33                   [16, 128, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# ├─Sequential: 1-7                        [16, 256, 10, 10]         --                        --                        [16, 128, 20, 20]         --
# │    └─BasicBlock: 2-5                   [16, 256, 10, 10]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-34                 [16, 256, 10, 10]         294,912                   471,859,200               [16, 128, 20, 20]         [3, 3]
# │    │    └─BatchNorm2d: 3-35            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─Identity: 3-36               [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-37                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Identity: 3-38               [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-39                 [16, 256, 10, 10]         589,824                   943,718,400               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-40            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─Sequential: 3-41             [16, 256, 10, 10]         --                        --                        [16, 128, 20, 20]         --
# │    │    │    └─Conv2d: 4-3             [16, 256, 10, 10]         32,768                    52,428,800                [16, 128, 20, 20]         [1, 1]
# │    │    │    └─BatchNorm2d: 4-4        [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-42                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    └─BasicBlock: 2-6                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-43                 [16, 256, 10, 10]         589,824                   943,718,400               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-44            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─Identity: 3-45               [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-46                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Identity: 3-47               [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-48                 [16, 256, 10, 10]         589,824                   943,718,400               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-49            [16, 256, 10, 10]         512                       8,192                     [16, 256, 10, 10]         --
# │    │    └─ReLU: 3-50                   [16, 256, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# ├─Sequential: 1-8                        [16, 512, 5, 5]           --                        --                        [16, 256, 10, 10]         --
# │    └─BasicBlock: 2-7                   [16, 512, 5, 5]           --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-51                 [16, 512, 5, 5]           1,179,648                 471,859,200               [16, 256, 10, 10]         [3, 3]
# │    │    └─BatchNorm2d: 3-52            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─Identity: 3-53               [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-54                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Identity: 3-55               [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Conv2d: 3-56                 [16, 512, 5, 5]           2,359,296                 943,718,400               [16, 512, 5, 5]           [3, 3]
# │    │    └─BatchNorm2d: 3-57            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─Sequential: 3-58             [16, 512, 5, 5]           --                        --                        [16, 256, 10, 10]         --
# │    │    │    └─Conv2d: 4-5             [16, 512, 5, 5]           131,072                   52,428,800                [16, 256, 10, 10]         [1, 1]
# │    │    │    └─BatchNorm2d: 4-6        [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-59                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    └─BasicBlock: 2-8                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Conv2d: 3-60                 [16, 512, 5, 5]           2,359,296                 943,718,400               [16, 512, 5, 5]           [3, 3]
# │    │    └─BatchNorm2d: 3-61            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─Identity: 3-62               [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-63                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Identity: 3-64               [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# │    │    └─Conv2d: 3-65                 [16, 512, 5, 5]           2,359,296                 943,718,400               [16, 512, 5, 5]           [3, 3]
# │    │    └─BatchNorm2d: 3-66            [16, 512, 5, 5]           1,024                     16,384                    [16, 512, 5, 5]           --
# │    │    └─ReLU: 3-67                   [16, 512, 5, 5]           --                        --                        [16, 512, 5, 5]           --
# ├─SelectAdaptivePool2d: 1-9              [16, 512]                 --                        --                        [16, 512, 5, 5]           --
# │    └─AdaptiveAvgPool2d: 2-9            [16, 512, 1, 1]           --                        --                        [16, 512, 5, 5]           --
# │    └─Flatten: 2-10                     [16, 512]                 --                        --                        [16, 512, 1, 1]           --
# ├─Linear: 1-10                           [16, 10]                  5,130                     82,080                    [16, 512]                 --
# =====================================================================================================================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# Total mult-adds (G): 14.80
# =====================================================================================================================================================================
# Input size (MB): 4.92
# Forward/backward pass size (MB): 324.40
# Params size (MB): 44.73
# Estimated Total Size (MB): 374.05
# =====================================================================================================================================================================

# %% [markdown]
# ### ResNet (from miniai)

# %%
run_algorithm('miniai_resnet')
# Out:
# name          operation       activations         params      flops
# ------------  --------------  ----------------  --------  ---------
# input_1       input           (16, 1, 28, 28)          0          0
# _0_0          nn.Conv2d       (16, 16, 28, 28)       416   10035200
# _0_1          nn.BatchNorm2d  (16, 16, 28, 28)        32     401408
# _0_2          nn.ReLU         (16, 16, 28, 28)         0          0
# _1_convs_0_0  nn.Conv2d       (16, 32, 28, 28)      4640  115605504
# _1_convs_0_1  nn.BatchNorm2d  (16, 32, 28, 28)        64     802816
# _1_convs_0_2  nn.ReLU         (16, 32, 28, 28)         0          0
# _1_convs_1_0  nn.Conv2d       (16, 32, 14, 14)      9248   57802752
# _1_convs_1_1  nn.BatchNorm2d  (16, 32, 14, 14)        64     200704
# _1_pool       nn.AvgPool2d    (16, 16, 14, 14)         0     100352
# _1_idconv_0   nn.Conv2d       (16, 32, 14, 14)       544    3211264
# add           add()           (16, 32, 14, 14)         0          0
# _1_act        nn.ReLU         (16, 32, 14, 14)         0          0
# _2_convs_0_0  nn.Conv2d       (16, 64, 14, 14)     18496  115605504
# _2_convs_0_1  nn.BatchNorm2d  (16, 64, 14, 14)       128     401408
# _2_convs_0_2  nn.ReLU         (16, 64, 14, 14)         0          0
# _2_convs_1_0  nn.Conv2d       (16, 64, 7, 7)       36928   57802752
# _2_convs_1_1  nn.BatchNorm2d  (16, 64, 7, 7)         128     100352
# _2_pool       nn.AvgPool2d    (16, 32, 7, 7)           0      50176
# _2_idconv_0   nn.Conv2d       (16, 64, 7, 7)        2112    3211264
# add_1         add()           (16, 64, 7, 7)           0          0
# _2_act        nn.ReLU         (16, 64, 7, 7)           0          0
# _3_convs_0_0  nn.Conv2d       (16, 128, 7, 7)      73856  115605504
# _3_convs_0_1  nn.BatchNorm2d  (16, 128, 7, 7)        256     200704
# _3_convs_0_2  nn.ReLU         (16, 128, 7, 7)          0          0
# _3_convs_1_0  nn.Conv2d       (16, 128, 4, 4)     147584   75497472
# _3_convs_1_1  nn.BatchNorm2d  (16, 128, 4, 4)        256      65536
# _3_pool       nn.AvgPool2d    (16, 64, 4, 4)           0      32768
# _3_idconv_0   nn.Conv2d       (16, 128, 4, 4)       8320    4194304
# add_2         add()           (16, 128, 4, 4)          0          0
# _3_act        nn.ReLU         (16, 128, 4, 4)          0          0
# _4_convs_0_0  nn.Conv2d       (16, 256, 4, 4)     295168  150994944
# _4_convs_0_1  nn.BatchNorm2d  (16, 256, 4, 4)        512     131072
# _4_convs_0_2  nn.ReLU         (16, 256, 4, 4)          0          0
# _4_convs_1_0  nn.Conv2d       (16, 256, 2, 2)     590080   75497472
# _4_convs_1_1  nn.BatchNorm2d  (16, 256, 2, 2)        512      32768
# _4_pool       nn.AvgPool2d    (16, 128, 2, 2)          0      16384
# _4_idconv_0   nn.Conv2d       (16, 256, 2, 2)      33024    4194304
# add_3         add()           (16, 256, 2, 2)          0          0
# _4_act        nn.ReLU         (16, 256, 2, 2)          0          0
# mean                          (16, 256)                0          0
# _6            nn.Linear       (16, 10)              2560      81920
# _7            nn.BatchNorm1d  (16, 10)                20        320
# output        output          (16, 10)                 0          0

# %%
run_comparison('miniai_resnet')
# Out:
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #                   Mult-Adds                 Input Shape               Kernel Shape
# =====================================================================================================================================================================
# Sequential                               [16, 10]                  --                        --                        [16, 1, 28, 28]           --
# ├─Sequential: 1-1                        [16, 16, 28, 28]          --                        --                        [16, 1, 28, 28]           --
# │    └─Conv2d: 2-1                       [16, 16, 28, 28]          416                       5,218,304                 [16, 1, 28, 28]           [5, 5]
# │    └─BatchNorm2d: 2-2                  [16, 16, 28, 28]          32                        512                       [16, 16, 28, 28]          --
# │    └─ReLU: 2-3                         [16, 16, 28, 28]          --                        --                        [16, 16, 28, 28]          --
# ├─ResBlock: 1-2                          [16, 32, 14, 14]          --                        --                        [16, 16, 28, 28]          --
# │    └─Sequential: 2-4                   [16, 32, 14, 14]          --                        --                        [16, 16, 28, 28]          --
# │    │    └─Sequential: 3-1              [16, 32, 28, 28]          --                        --                        [16, 16, 28, 28]          --
# │    │    │    └─Conv2d: 4-1             [16, 32, 28, 28]          4,640                     58,204,160                [16, 16, 28, 28]          [3, 3]
# │    │    │    └─BatchNorm2d: 4-2        [16, 32, 28, 28]          64                        1,024                     [16, 32, 28, 28]          --
# │    │    │    └─ReLU: 4-3               [16, 32, 28, 28]          --                        --                        [16, 32, 28, 28]          --
# │    │    └─Sequential: 3-2              [16, 32, 14, 14]          --                        --                        [16, 32, 28, 28]          --
# │    │    │    └─Conv2d: 4-4             [16, 32, 14, 14]          9,248                     29,001,728                [16, 32, 28, 28]          [3, 3]
# │    │    │    └─BatchNorm2d: 4-5        [16, 32, 14, 14]          64                        1,024                     [16, 32, 14, 14]          --
# │    └─AvgPool2d: 2-5                    [16, 16, 14, 14]          --                        --                        [16, 16, 28, 28]          2
# │    └─Sequential: 2-6                   [16, 32, 14, 14]          --                        --                        [16, 16, 14, 14]          --
# │    │    └─Conv2d: 3-3                  [16, 32, 14, 14]          544                       1,705,984                 [16, 16, 14, 14]          [1, 1]
# │    └─ReLU: 2-7                         [16, 32, 14, 14]          --                        --                        [16, 32, 14, 14]          --
# ├─ResBlock: 1-3                          [16, 64, 7, 7]            --                        --                        [16, 32, 14, 14]          --
# │    └─Sequential: 2-8                   [16, 64, 7, 7]            --                        --                        [16, 32, 14, 14]          --
# │    │    └─Sequential: 3-4              [16, 64, 14, 14]          --                        --                        [16, 32, 14, 14]          --
# │    │    │    └─Conv2d: 4-6             [16, 64, 14, 14]          18,496                    58,003,456                [16, 32, 14, 14]          [3, 3]
# │    │    │    └─BatchNorm2d: 4-7        [16, 64, 14, 14]          128                       2,048                     [16, 64, 14, 14]          --
# │    │    │    └─ReLU: 4-8               [16, 64, 14, 14]          --                        --                        [16, 64, 14, 14]          --
# │    │    └─Sequential: 3-5              [16, 64, 7, 7]            --                        --                        [16, 64, 14, 14]          --
# │    │    │    └─Conv2d: 4-9             [16, 64, 7, 7]            36,928                    28,951,552                [16, 64, 14, 14]          [3, 3]
# │    │    │    └─BatchNorm2d: 4-10       [16, 64, 7, 7]            128                       2,048                     [16, 64, 7, 7]            --
# │    └─AvgPool2d: 2-9                    [16, 32, 7, 7]            --                        --                        [16, 32, 14, 14]          2
# │    └─Sequential: 2-10                  [16, 64, 7, 7]            --                        --                        [16, 32, 7, 7]            --
# │    │    └─Conv2d: 3-6                  [16, 64, 7, 7]            2,112                     1,655,808                 [16, 32, 7, 7]            [1, 1]
# │    └─ReLU: 2-11                        [16, 64, 7, 7]            --                        --                        [16, 64, 7, 7]            --
# ├─ResBlock: 1-4                          [16, 128, 4, 4]           --                        --                        [16, 64, 7, 7]            --
# │    └─Sequential: 2-12                  [16, 128, 4, 4]           --                        --                        [16, 64, 7, 7]            --
# │    │    └─Sequential: 3-7              [16, 128, 7, 7]           --                        --                        [16, 64, 7, 7]            --
# │    │    │    └─Conv2d: 4-11            [16, 128, 7, 7]           73,856                    57,903,104                [16, 64, 7, 7]            [3, 3]
# │    │    │    └─BatchNorm2d: 4-12       [16, 128, 7, 7]           256                       4,096                     [16, 128, 7, 7]           --
# │    │    │    └─ReLU: 4-13              [16, 128, 7, 7]           --                        --                        [16, 128, 7, 7]           --
# │    │    └─Sequential: 3-8              [16, 128, 4, 4]           --                        --                        [16, 128, 7, 7]           --
# │    │    │    └─Conv2d: 4-14            [16, 128, 4, 4]           147,584                   37,781,504                [16, 128, 7, 7]           [3, 3]
# │    │    │    └─BatchNorm2d: 4-15       [16, 128, 4, 4]           256                       4,096                     [16, 128, 4, 4]           --
# │    └─AvgPool2d: 2-13                   [16, 64, 4, 4]            --                        --                        [16, 64, 7, 7]            2
# │    └─Sequential: 2-14                  [16, 128, 4, 4]           --                        --                        [16, 64, 4, 4]            --
# │    │    └─Conv2d: 3-9                  [16, 128, 4, 4]           8,320                     2,129,920                 [16, 64, 4, 4]            [1, 1]
# │    └─ReLU: 2-15                        [16, 128, 4, 4]           --                        --                        [16, 128, 4, 4]           --
# ├─ResBlock: 1-5                          [16, 256, 2, 2]           --                        --                        [16, 128, 4, 4]           --
# │    └─Sequential: 2-16                  [16, 256, 2, 2]           --                        --                        [16, 128, 4, 4]           --
# │    │    └─Sequential: 3-10             [16, 256, 4, 4]           --                        --                        [16, 128, 4, 4]           --
# │    │    │    └─Conv2d: 4-16            [16, 256, 4, 4]           295,168                   75,563,008                [16, 128, 4, 4]           [3, 3]
# │    │    │    └─BatchNorm2d: 4-17       [16, 256, 4, 4]           512                       8,192                     [16, 256, 4, 4]           --
# │    │    │    └─ReLU: 4-18              [16, 256, 4, 4]           --                        --                        [16, 256, 4, 4]           --
# │    │    └─Sequential: 3-11             [16, 256, 2, 2]           --                        --                        [16, 256, 4, 4]           --
# │    │    │    └─Conv2d: 4-19            [16, 256, 2, 2]           590,080                   37,765,120                [16, 256, 4, 4]           [3, 3]
# │    │    │    └─BatchNorm2d: 4-20       [16, 256, 2, 2]           512                       8,192                     [16, 256, 2, 2]           --
# │    └─AvgPool2d: 2-17                   [16, 128, 2, 2]           --                        --                        [16, 128, 4, 4]           2
# │    └─Sequential: 2-18                  [16, 256, 2, 2]           --                        --                        [16, 128, 2, 2]           --
# │    │    └─Conv2d: 3-12                 [16, 256, 2, 2]           33,024                    2,113,536                 [16, 128, 2, 2]           [1, 1]
# │    └─ReLU: 2-19                        [16, 256, 2, 2]           --                        --                        [16, 256, 2, 2]           --
# ├─GlobalAvgPool: 1-6                     [16, 256]                 --                        --                        [16, 256, 2, 2]           --
# ├─Linear: 1-7                            [16, 10]                  2,560                     40,960                    [16, 256]                 --
# ├─BatchNorm1d: 1-8                       [16, 10]                  20                        320                       [16, 10]                  --
# =====================================================================================================================================================================
# Total params: 1,224,948
# Trainable params: 1,224,948
# Non-trainable params: 0
# Total mult-adds (M): 396.07
# =====================================================================================================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 20.29
# Params size (MB): 4.90
# Estimated Total Size (MB): 25.24
# =====================================================================================================================================================================

# %% [markdown]
# ### Autoencoder (from miniai)

# %%
run_algorithm('miniai_autoenc')
# Out:
# name            operation               activations           params        flops
# --------------  ----------------------  ------------------  --------  -----------
# input_1         input                   (16, 3, 160, 160)          0            0
# _0_convs_0_0    nn.Conv2d               (16, 32, 160, 160)      2432   1966080000
# _0_convs_0_1    nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# leaky_relu      leaky_relu()            (16, 32, 160, 160)         0            0
# sub             sub()                   (16, 32, 160, 160)         0            0
# _0_convs_1_0    nn.Conv2d               (16, 32, 160, 160)     25632  20971520000
# _0_convs_1_1    nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# _0_idconv_0     nn.Conv2d               (16, 32, 160, 160)       128     78643200
# add             add()                   (16, 32, 160, 160)         0            0
# leaky_relu_1    leaky_relu()            (16, 32, 160, 160)         0            0
# sub_1           sub()                   (16, 32, 160, 160)         0            0
# _1_convs_0_0    nn.Conv2d               (16, 64, 160, 160)     18496  15099494400
# _1_convs_0_1    nn.BatchNorm2d          (16, 64, 160, 160)       128     52428800
# leaky_relu_2    leaky_relu()            (16, 64, 160, 160)         0            0
# sub_2           sub()                   (16, 64, 160, 160)         0            0
# _1_convs_1_0    nn.Conv2d               (16, 64, 80, 80)       36928   7549747200
# _1_convs_1_1    nn.BatchNorm2d          (16, 64, 80, 80)         128     13107200
# _1_pool         nn.AvgPool2d            (16, 32, 80, 80)           0      6553600
# _1_idconv_0     nn.Conv2d               (16, 64, 80, 80)        2112    419430400
# add_1           add()                   (16, 64, 80, 80)           0            0
# leaky_relu_3    leaky_relu()            (16, 64, 80, 80)           0            0
# sub_3           sub()                   (16, 64, 80, 80)           0            0
# _2_convs_0_0    nn.Conv2d               (16, 128, 80, 80)      73856  15099494400
# _2_convs_0_1    nn.BatchNorm2d          (16, 128, 80, 80)        256     26214400
# leaky_relu_4    leaky_relu()            (16, 128, 80, 80)          0            0
# sub_4           sub()                   (16, 128, 80, 80)          0            0
# _2_convs_1_0    nn.Conv2d               (16, 128, 40, 40)     147584   7549747200
# _2_convs_1_1    nn.BatchNorm2d          (16, 128, 40, 40)        256      6553600
# _2_pool         nn.AvgPool2d            (16, 64, 40, 40)           0      3276800
# _2_idconv_0     nn.Conv2d               (16, 128, 40, 40)       8320    419430400
# add_2           add()                   (16, 128, 40, 40)          0            0
# leaky_relu_5    leaky_relu()            (16, 128, 40, 40)          0            0
# sub_5           sub()                   (16, 128, 40, 40)          0            0
# _3_convs_0_0    nn.Conv2d               (16, 256, 40, 40)     295168  15099494400
# _3_convs_0_1    nn.BatchNorm2d          (16, 256, 40, 40)        512     13107200
# leaky_relu_6    leaky_relu()            (16, 256, 40, 40)          0            0
# sub_6           sub()                   (16, 256, 40, 40)          0            0
# _3_convs_1_0    nn.Conv2d               (16, 256, 20, 20)     590080   7549747200
# _3_convs_1_1    nn.BatchNorm2d          (16, 256, 20, 20)        512      3276800
# _3_pool         nn.AvgPool2d            (16, 128, 20, 20)          0      1638400
# _3_idconv_0     nn.Conv2d               (16, 256, 20, 20)      33024    419430400
# add_3           add()                   (16, 256, 20, 20)          0            0
# leaky_relu_7    leaky_relu()            (16, 256, 20, 20)          0            0
# sub_7           sub()                   (16, 256, 20, 20)          0            0
# _4_convs_0_0    nn.Conv2d               (16, 512, 20, 20)    1180160  15099494400
# _4_convs_0_1    nn.BatchNorm2d          (16, 512, 20, 20)       1024      6553600
# leaky_relu_8    leaky_relu()            (16, 512, 20, 20)          0            0
# sub_8           sub()                   (16, 512, 20, 20)          0            0
# _4_convs_1_0    nn.Conv2d               (16, 512, 10, 10)    2359808   7549747200
# _4_convs_1_1    nn.BatchNorm2d          (16, 512, 10, 10)       1024      1638400
# _4_pool         nn.AvgPool2d            (16, 256, 10, 10)          0       819200
# _4_idconv_0     nn.Conv2d               (16, 512, 10, 10)     131584    419430400
# add_4           add()                   (16, 512, 10, 10)          0            0
# leaky_relu_9    leaky_relu()            (16, 512, 10, 10)          0            0
# sub_9           sub()                   (16, 512, 10, 10)          0            0
# _5_0            nn.UpsamplingNearest2d  (16, 512, 20, 20)          0            0
# _5_1_convs_0_0  nn.Conv2d               (16, 256, 20, 20)    1179904  15099494400
# _5_1_convs_0_1  nn.BatchNorm2d          (16, 256, 20, 20)        512      3276800
# leaky_relu_10   leaky_relu()            (16, 256, 20, 20)          0            0
# sub_10          sub()                   (16, 256, 20, 20)          0            0
# _5_1_convs_1_0  nn.Conv2d               (16, 256, 20, 20)     590080   7549747200
# _5_1_convs_1_1  nn.BatchNorm2d          (16, 256, 20, 20)        512      3276800
# _5_1_idconv_0   nn.Conv2d               (16, 256, 20, 20)     131328   1677721600
# add_5           add()                   (16, 256, 20, 20)          0            0
# leaky_relu_11   leaky_relu()            (16, 256, 20, 20)          0            0
# sub_11          sub()                   (16, 256, 20, 20)          0            0
# _6_0            nn.UpsamplingNearest2d  (16, 256, 40, 40)          0            0
# _6_1_convs_0_0  nn.Conv2d               (16, 128, 40, 40)     295040  15099494400
# _6_1_convs_0_1  nn.BatchNorm2d          (16, 128, 40, 40)        256      6553600
# leaky_relu_12   leaky_relu()            (16, 128, 40, 40)          0            0
# sub_12          sub()                   (16, 128, 40, 40)          0            0
# _6_1_convs_1_0  nn.Conv2d               (16, 128, 40, 40)     147584   7549747200
# _6_1_convs_1_1  nn.BatchNorm2d          (16, 128, 40, 40)        256      6553600
# _6_1_idconv_0   nn.Conv2d               (16, 128, 40, 40)      32896   1677721600
# add_6           add()                   (16, 128, 40, 40)          0            0
# leaky_relu_13   leaky_relu()            (16, 128, 40, 40)          0            0
# sub_13          sub()                   (16, 128, 40, 40)          0            0
# _7_0            nn.UpsamplingNearest2d  (16, 128, 80, 80)          0            0
# _7_1_convs_0_0  nn.Conv2d               (16, 64, 80, 80)       73792  15099494400
# _7_1_convs_0_1  nn.BatchNorm2d          (16, 64, 80, 80)         128     13107200
# leaky_relu_14   leaky_relu()            (16, 64, 80, 80)           0            0
# sub_14          sub()                   (16, 64, 80, 80)           0            0
# _7_1_convs_1_0  nn.Conv2d               (16, 64, 80, 80)       36928   7549747200
# _7_1_convs_1_1  nn.BatchNorm2d          (16, 64, 80, 80)         128     13107200
# _7_1_idconv_0   nn.Conv2d               (16, 64, 80, 80)        8256   1677721600
# add_7           add()                   (16, 64, 80, 80)           0            0
# leaky_relu_15   leaky_relu()            (16, 64, 80, 80)           0            0
# sub_15          sub()                   (16, 64, 80, 80)           0            0
# _8_0            nn.UpsamplingNearest2d  (16, 64, 160, 160)         0            0
# _8_1_convs_0_0  nn.Conv2d               (16, 32, 160, 160)     18464  15099494400
# _8_1_convs_0_1  nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# leaky_relu_16   leaky_relu()            (16, 32, 160, 160)         0            0
# sub_16          sub()                   (16, 32, 160, 160)         0            0
# _8_1_convs_1_0  nn.Conv2d               (16, 32, 160, 160)      9248   7549747200
# _8_1_convs_1_1  nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# _8_1_idconv_0   nn.Conv2d               (16, 32, 160, 160)      2080   1677721600
# add_8           add()                   (16, 32, 160, 160)         0            0
# leaky_relu_17   leaky_relu()            (16, 32, 160, 160)         0            0
# sub_17          sub()                   (16, 32, 160, 160)         0            0
# _9_convs_0_0    nn.Conv2d               (16, 3, 160, 160)        867    707788800
# _9_convs_0_1    nn.BatchNorm2d          (16, 3, 160, 160)          6      2457600
# _9_convs_0_2    nn.Identity             (16, 3, 160, 160)          0            0
# _9_convs_1_0    nn.Conv2d               (16, 3, 160, 160)         84     66355200
# _9_convs_1_1    nn.BatchNorm2d          (16, 3, 160, 160)          6      2457600
# _9_idconv_0     nn.Conv2d               (16, 3, 160, 160)         99     78643200
# add_9           add()                   (16, 3, 160, 160)          0            0
# _9_act          nn.Identity             (16, 3, 160, 160)          0            0
# output          output                  (16, 3, 160, 160)          0            0

# %%
run_comparison('miniai_autoenc')
# Out:
# ==========================================================================================================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #                   Mult-Adds                 Input Shape               Kernel Shape
# ==========================================================================================================================================================================
# Sequential                                    [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# ├─ResBlock: 1-1                               [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    └─Sequential: 2-1                        [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    │    └─Sequential: 3-1                   [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    │    │    └─Conv2d: 4-1                  [16, 32, 160, 160]        2,432                     996,147,200               [16, 3, 160, 160]         [5, 5]
# │    │    │    └─BatchNorm2d: 4-2             [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    │    │    └─GeneralRelu: 4-3             [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    └─Sequential: 3-2                   [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Conv2d: 4-4                  [16, 32, 160, 160]        25,632                    10,498,867,200            [16, 32, 160, 160]        [5, 5]
# │    │    │    └─BatchNorm2d: 4-5             [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    └─Sequential: 2-2                        [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    │    └─Conv2d: 3-3                       [16, 32, 160, 160]        128                       52,428,800                [16, 3, 160, 160]         [1, 1]
# │    └─GeneralRelu: 2-3                       [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# ├─ResBlock: 1-2                               [16, 64, 80, 80]          --                        --                        [16, 32, 160, 160]        --
# │    └─Sequential: 2-4                        [16, 64, 80, 80]          --                        --                        [16, 32, 160, 160]        --
# │    │    └─Sequential: 3-4                   [16, 64, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Conv2d: 4-6                  [16, 64, 160, 160]        18,496                    7,575,961,600             [16, 32, 160, 160]        [3, 3]
# │    │    │    └─BatchNorm2d: 4-7             [16, 64, 160, 160]        128                       2,048                     [16, 64, 160, 160]        --
# │    │    │    └─GeneralRelu: 4-8             [16, 64, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    └─Sequential: 3-5                   [16, 64, 80, 80]          --                        --                        [16, 64, 160, 160]        --
# │    │    │    └─Conv2d: 4-9                  [16, 64, 80, 80]          36,928                    3,781,427,200             [16, 64, 160, 160]        [3, 3]
# │    │    │    └─BatchNorm2d: 4-10            [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# │    └─AvgPool2d: 2-5                         [16, 32, 80, 80]          --                        --                        [16, 32, 160, 160]        2
# │    └─Sequential: 2-6                        [16, 64, 80, 80]          --                        --                        [16, 32, 80, 80]          --
# │    │    └─Conv2d: 3-6                       [16, 64, 80, 80]          2,112                     216,268,800               [16, 32, 80, 80]          [1, 1]
# │    └─GeneralRelu: 2-7                       [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# ├─ResBlock: 1-3                               [16, 128, 40, 40]         --                        --                        [16, 64, 80, 80]          --
# │    └─Sequential: 2-8                        [16, 128, 40, 40]         --                        --                        [16, 64, 80, 80]          --
# │    │    └─Sequential: 3-7                   [16, 128, 80, 80]         --                        --                        [16, 64, 80, 80]          --
# │    │    │    └─Conv2d: 4-11                 [16, 128, 80, 80]         73,856                    7,562,854,400             [16, 64, 80, 80]          [3, 3]
# │    │    │    └─BatchNorm2d: 4-12            [16, 128, 80, 80]         256                       4,096                     [16, 128, 80, 80]         --
# │    │    │    └─GeneralRelu: 4-13            [16, 128, 80, 80]         --                        --                        [16, 128, 80, 80]         --
# │    │    └─Sequential: 3-8                   [16, 128, 40, 40]         --                        --                        [16, 128, 80, 80]         --
# │    │    │    └─Conv2d: 4-14                 [16, 128, 40, 40]         147,584                   3,778,150,400             [16, 128, 80, 80]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-15            [16, 128, 40, 40]         256                       4,096                     [16, 128, 40, 40]         --
# │    └─AvgPool2d: 2-9                         [16, 64, 40, 40]          --                        --                        [16, 64, 80, 80]          2
# │    └─Sequential: 2-10                       [16, 128, 40, 40]         --                        --                        [16, 64, 40, 40]          --
# │    │    └─Conv2d: 3-9                       [16, 128, 40, 40]         8,320                     212,992,000               [16, 64, 40, 40]          [1, 1]
# │    └─GeneralRelu: 2-11                      [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# ├─ResBlock: 1-4                               [16, 256, 20, 20]         --                        --                        [16, 128, 40, 40]         --
# │    └─Sequential: 2-12                       [16, 256, 20, 20]         --                        --                        [16, 128, 40, 40]         --
# │    │    └─Sequential: 3-10                  [16, 256, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    │    │    └─Conv2d: 4-16                 [16, 256, 40, 40]         295,168                   7,556,300,800             [16, 128, 40, 40]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-17            [16, 256, 40, 40]         512                       8,192                     [16, 256, 40, 40]         --
# │    │    │    └─GeneralRelu: 4-18            [16, 256, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    └─Sequential: 3-11                  [16, 256, 20, 20]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    └─Conv2d: 4-19                 [16, 256, 20, 20]         590,080                   3,776,512,000             [16, 256, 40, 40]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-20            [16, 256, 20, 20]         512                       8,192                     [16, 256, 20, 20]         --
# │    └─AvgPool2d: 2-13                        [16, 128, 20, 20]         --                        --                        [16, 128, 40, 40]         2
# │    └─Sequential: 2-14                       [16, 256, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    └─Conv2d: 3-12                      [16, 256, 20, 20]         33,024                    211,353,600               [16, 128, 20, 20]         [1, 1]
# │    └─GeneralRelu: 2-15                      [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# ├─ResBlock: 1-5                               [16, 512, 10, 10]         --                        --                        [16, 256, 20, 20]         --
# │    └─Sequential: 2-16                       [16, 512, 10, 10]         --                        --                        [16, 256, 20, 20]         --
# │    │    └─Sequential: 3-13                  [16, 512, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    │    │    └─Conv2d: 4-21                 [16, 512, 20, 20]         1,180,160                 7,553,024,000             [16, 256, 20, 20]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-22            [16, 512, 20, 20]         1,024                     16,384                    [16, 512, 20, 20]         --
# │    │    │    └─GeneralRelu: 4-23            [16, 512, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    └─Sequential: 3-14                  [16, 512, 10, 10]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    └─Conv2d: 4-24                 [16, 512, 10, 10]         2,359,808                 3,775,692,800             [16, 512, 20, 20]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-25            [16, 512, 10, 10]         1,024                     16,384                    [16, 512, 10, 10]         --
# │    └─AvgPool2d: 2-17                        [16, 256, 10, 10]         --                        --                        [16, 256, 20, 20]         2
# │    └─Sequential: 2-18                       [16, 512, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    └─Conv2d: 3-15                      [16, 512, 10, 10]         131,584                   210,534,400               [16, 256, 10, 10]         [1, 1]
# │    └─GeneralRelu: 2-19                      [16, 512, 10, 10]         --                        --                        [16, 512, 10, 10]         --
# ├─Sequential: 1-6                             [16, 256, 20, 20]         --                        --                        [16, 512, 10, 10]         --
# │    └─UpsamplingNearest2d: 2-20              [16, 512, 20, 20]         --                        --                        [16, 512, 10, 10]         --
# │    └─ResBlock: 2-21                         [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    └─Sequential: 3-16                  [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    └─Sequential: 4-26             [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    │    └─Conv2d: 5-1             [16, 256, 20, 20]         1,179,904                 7,551,385,600             [16, 512, 20, 20]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-2        [16, 256, 20, 20]         512                       8,192                     [16, 256, 20, 20]         --
# │    │    │    │    └─GeneralRelu: 5-3        [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    │    │    └─Sequential: 4-27             [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    │    │    │    └─Conv2d: 5-4             [16, 256, 20, 20]         590,080                   3,776,512,000             [16, 256, 20, 20]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-5        [16, 256, 20, 20]         512                       8,192                     [16, 256, 20, 20]         --
# │    │    └─Sequential: 3-17                  [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    └─Conv2d: 4-28                 [16, 256, 20, 20]         131,328                   840,499,200               [16, 512, 20, 20]         [1, 1]
# │    │    └─GeneralRelu: 3-18                 [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# ├─Sequential: 1-7                             [16, 128, 40, 40]         --                        --                        [16, 256, 20, 20]         --
# │    └─UpsamplingNearest2d: 2-22              [16, 256, 40, 40]         --                        --                        [16, 256, 20, 20]         --
# │    └─ResBlock: 2-23                         [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    └─Sequential: 3-19                  [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    └─Sequential: 4-29             [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    │    └─Conv2d: 5-6             [16, 128, 40, 40]         295,040                   7,553,024,000             [16, 256, 40, 40]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-7        [16, 128, 40, 40]         256                       4,096                     [16, 128, 40, 40]         --
# │    │    │    │    └─GeneralRelu: 5-8        [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    │    │    └─Sequential: 4-30             [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    │    │    │    └─Conv2d: 5-9             [16, 128, 40, 40]         147,584                   3,778,150,400             [16, 128, 40, 40]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-10       [16, 128, 40, 40]         256                       4,096                     [16, 128, 40, 40]         --
# │    │    └─Sequential: 3-20                  [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    └─Conv2d: 4-31                 [16, 128, 40, 40]         32,896                    842,137,600               [16, 256, 40, 40]         [1, 1]
# │    │    └─GeneralRelu: 3-21                 [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# ├─Sequential: 1-8                             [16, 64, 80, 80]          --                        --                        [16, 128, 40, 40]         --
# │    └─UpsamplingNearest2d: 2-24              [16, 128, 80, 80]         --                        --                        [16, 128, 40, 40]         --
# │    └─ResBlock: 2-25                         [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    └─Sequential: 3-22                  [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    │    └─Sequential: 4-32             [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    │    │    └─Conv2d: 5-11            [16, 64, 80, 80]          73,792                    7,556,300,800             [16, 128, 80, 80]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-12       [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# │    │    │    │    └─GeneralRelu: 5-13       [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# │    │    │    └─Sequential: 4-33             [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# │    │    │    │    └─Conv2d: 5-14            [16, 64, 80, 80]          36,928                    3,781,427,200             [16, 64, 80, 80]          [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-15       [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# │    │    └─Sequential: 3-23                  [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    │    └─Conv2d: 4-34                 [16, 64, 80, 80]          8,256                     845,414,400               [16, 128, 80, 80]         [1, 1]
# │    │    └─GeneralRelu: 3-24                 [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# ├─Sequential: 1-9                             [16, 32, 160, 160]        --                        --                        [16, 64, 80, 80]          --
# │    └─UpsamplingNearest2d: 2-26              [16, 64, 160, 160]        --                        --                        [16, 64, 80, 80]          --
# │    └─ResBlock: 2-27                         [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    └─Sequential: 3-25                  [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    └─Sequential: 4-35             [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    │    └─Conv2d: 5-16            [16, 32, 160, 160]        18,464                    7,562,854,400             [16, 64, 160, 160]        [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-17       [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    │    │    │    └─GeneralRelu: 5-18       [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Sequential: 4-36             [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    │    └─Conv2d: 5-19            [16, 32, 160, 160]        9,248                     3,787,980,800             [16, 32, 160, 160]        [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-20       [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    │    └─Sequential: 3-26                  [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    └─Conv2d: 4-37                 [16, 32, 160, 160]        2,080                     851,968,000               [16, 64, 160, 160]        [1, 1]
# │    │    └─GeneralRelu: 3-27                 [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# ├─ResBlock: 1-10                              [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    └─Sequential: 2-28                       [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    │    └─Sequential: 3-28                  [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Conv2d: 4-38                 [16, 3, 160, 160]         867                       355,123,200               [16, 32, 160, 160]        [3, 3]
# │    │    │    └─BatchNorm2d: 4-39            [16, 3, 160, 160]         6                         96                        [16, 3, 160, 160]         --
# │    │    │    └─Identity: 4-40               [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    └─Sequential: 3-29                  [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    │    └─Conv2d: 4-41                 [16, 3, 160, 160]         84                        34,406,400                [16, 3, 160, 160]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-42            [16, 3, 160, 160]         6                         96                        [16, 3, 160, 160]         --
# │    └─Sequential: 2-29                       [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    │    └─Conv2d: 3-30                      [16, 3, 160, 160]         99                        40,550,400                [16, 32, 160, 160]        [1, 1]
# │    └─Identity: 2-30                         [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# ==========================================================================================================================================================================
# Total params: 7,437,862
# Trainable params: 7,437,862
# Non-trainable params: 0
# Total mult-adds (G): 106.92
# ==========================================================================================================================================================================
# Input size (MB): 4.92
# Forward/backward pass size (MB): 2637.82
# Params size (MB): 29.75
# Estimated Total Size (MB): 2672.49
# ==========================================================================================================================================================================

# %% [markdown]
# ### UNet (from miniai)

# %%
run_algorithm('miniai_unet')
# Out:
# name              operation               activations           params        flops
# ----------------  ----------------------  ------------------  --------  -----------
# x                 input                   (16, 3, 160, 160)          0            0
# start_convs_0_0   nn.Conv2d               (16, 32, 160, 160)       896    707788800
# start_convs_0_1   nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# leaky_relu        leaky_relu()            (16, 32, 160, 160)         0            0
# sub               sub()                   (16, 32, 160, 160)         0            0
# start_convs_1_0   nn.Conv2d               (16, 32, 160, 160)      9248   7549747200
# start_convs_1_1   nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# start_idconv_0    nn.Conv2d               (16, 32, 160, 160)       128     78643200
# add               add()                   (16, 32, 160, 160)         0            0
# leaky_relu_1      leaky_relu()            (16, 32, 160, 160)         0            0
# sub_1             sub()                   (16, 32, 160, 160)         0            0
# dn_0_convs_0_0    nn.Conv2d               (16, 64, 160, 160)     18496  15099494400
# dn_0_convs_0_1    nn.BatchNorm2d          (16, 64, 160, 160)       128     52428800
# leaky_relu_2      leaky_relu()            (16, 64, 160, 160)         0            0
# sub_2             sub()                   (16, 64, 160, 160)         0            0
# dn_0_convs_1_0    nn.Conv2d               (16, 64, 80, 80)       36928   7549747200
# dn_0_convs_1_1    nn.BatchNorm2d          (16, 64, 80, 80)         128     13107200
# dn_0_pool         nn.AvgPool2d            (16, 32, 80, 80)           0      6553600
# dn_0_idconv_0     nn.Conv2d               (16, 64, 80, 80)        2112    419430400
# add_1             add()                   (16, 64, 80, 80)           0            0
# leaky_relu_3      leaky_relu()            (16, 64, 80, 80)           0            0
# sub_3             sub()                   (16, 64, 80, 80)           0            0
# dn_1_convs_0_0    nn.Conv2d               (16, 128, 80, 80)      73856  15099494400
# dn_1_convs_0_1    nn.BatchNorm2d          (16, 128, 80, 80)        256     26214400
# leaky_relu_4      leaky_relu()            (16, 128, 80, 80)          0            0
# sub_4             sub()                   (16, 128, 80, 80)          0            0
# dn_1_convs_1_0    nn.Conv2d               (16, 128, 40, 40)     147584   7549747200
# dn_1_convs_1_1    nn.BatchNorm2d          (16, 128, 40, 40)        256      6553600
# dn_1_pool         nn.AvgPool2d            (16, 64, 40, 40)           0      3276800
# dn_1_idconv_0     nn.Conv2d               (16, 128, 40, 40)       8320    419430400
# add_2             add()                   (16, 128, 40, 40)          0            0
# leaky_relu_5      leaky_relu()            (16, 128, 40, 40)          0            0
# sub_5             sub()                   (16, 128, 40, 40)          0            0
# dn_2_convs_0_0    nn.Conv2d               (16, 256, 40, 40)     295168  15099494400
# dn_2_convs_0_1    nn.BatchNorm2d          (16, 256, 40, 40)        512     13107200
# leaky_relu_6      leaky_relu()            (16, 256, 40, 40)          0            0
# sub_6             sub()                   (16, 256, 40, 40)          0            0
# dn_2_convs_1_0    nn.Conv2d               (16, 256, 20, 20)     590080   7549747200
# dn_2_convs_1_1    nn.BatchNorm2d          (16, 256, 20, 20)        512      3276800
# dn_2_pool         nn.AvgPool2d            (16, 128, 20, 20)          0      1638400
# dn_2_idconv_0     nn.Conv2d               (16, 256, 20, 20)      33024    419430400
# add_3             add()                   (16, 256, 20, 20)          0            0
# leaky_relu_7      leaky_relu()            (16, 256, 20, 20)          0            0
# sub_7             sub()                   (16, 256, 20, 20)          0            0
# dn_3_convs_0_0    nn.Conv2d               (16, 512, 20, 20)    1180160  15099494400
# dn_3_convs_0_1    nn.BatchNorm2d          (16, 512, 20, 20)       1024      6553600
# leaky_relu_8      leaky_relu()            (16, 512, 20, 20)          0            0
# sub_8             sub()                   (16, 512, 20, 20)          0            0
# dn_3_convs_1_0    nn.Conv2d               (16, 512, 10, 10)    2359808   7549747200
# dn_3_convs_1_1    nn.BatchNorm2d          (16, 512, 10, 10)       1024      1638400
# dn_3_pool         nn.AvgPool2d            (16, 256, 10, 10)          0       819200
# dn_3_idconv_0     nn.Conv2d               (16, 512, 10, 10)     131584    419430400
# add_4             add()                   (16, 512, 10, 10)          0            0
# leaky_relu_9      leaky_relu()            (16, 512, 10, 10)          0            0
# sub_9             sub()                   (16, 512, 10, 10)          0            0
# up_0_0            nn.UpsamplingNearest2d  (16, 512, 20, 20)          0            0
# up_0_1_convs_0_0  nn.Conv2d               (16, 256, 20, 20)    1179904  15099494400
# up_0_1_convs_0_1  nn.BatchNorm2d          (16, 256, 20, 20)        512      3276800
# leaky_relu_10     leaky_relu()            (16, 256, 20, 20)          0            0
# sub_10            sub()                   (16, 256, 20, 20)          0            0
# up_0_1_convs_1_0  nn.Conv2d               (16, 256, 20, 20)     590080   7549747200
# up_0_1_convs_1_1  nn.BatchNorm2d          (16, 256, 20, 20)        512      3276800
# up_0_1_idconv_0   nn.Conv2d               (16, 256, 20, 20)     131328   1677721600
# add_5             add()                   (16, 256, 20, 20)          0            0
# leaky_relu_11     leaky_relu()            (16, 256, 20, 20)          0            0
# sub_11            sub()                   (16, 256, 20, 20)          0            0
# add_6             add()                   (16, 256, 20, 20)          0            0
# up_1_0            nn.UpsamplingNearest2d  (16, 256, 40, 40)          0            0
# up_1_1_convs_0_0  nn.Conv2d               (16, 128, 40, 40)     295040  15099494400
# up_1_1_convs_0_1  nn.BatchNorm2d          (16, 128, 40, 40)        256      6553600
# leaky_relu_12     leaky_relu()            (16, 128, 40, 40)          0            0
# sub_12            sub()                   (16, 128, 40, 40)          0            0
# up_1_1_convs_1_0  nn.Conv2d               (16, 128, 40, 40)     147584   7549747200
# up_1_1_convs_1_1  nn.BatchNorm2d          (16, 128, 40, 40)        256      6553600
# up_1_1_idconv_0   nn.Conv2d               (16, 128, 40, 40)      32896   1677721600
# add_7             add()                   (16, 128, 40, 40)          0            0
# leaky_relu_13     leaky_relu()            (16, 128, 40, 40)          0            0
# sub_13            sub()                   (16, 128, 40, 40)          0            0
# add_8             add()                   (16, 128, 40, 40)          0            0
# up_2_0            nn.UpsamplingNearest2d  (16, 128, 80, 80)          0            0
# up_2_1_convs_0_0  nn.Conv2d               (16, 64, 80, 80)       73792  15099494400
# up_2_1_convs_0_1  nn.BatchNorm2d          (16, 64, 80, 80)         128     13107200
# leaky_relu_14     leaky_relu()            (16, 64, 80, 80)           0            0
# sub_14            sub()                   (16, 64, 80, 80)           0            0
# up_2_1_convs_1_0  nn.Conv2d               (16, 64, 80, 80)       36928   7549747200
# up_2_1_convs_1_1  nn.BatchNorm2d          (16, 64, 80, 80)         128     13107200
# up_2_1_idconv_0   nn.Conv2d               (16, 64, 80, 80)        8256   1677721600
# add_9             add()                   (16, 64, 80, 80)           0            0
# leaky_relu_15     leaky_relu()            (16, 64, 80, 80)           0            0
# sub_15            sub()                   (16, 64, 80, 80)           0            0
# add_10            add()                   (16, 64, 80, 80)           0            0
# up_3_0            nn.UpsamplingNearest2d  (16, 64, 160, 160)         0            0
# up_3_1_convs_0_0  nn.Conv2d               (16, 32, 160, 160)     18464  15099494400
# up_3_1_convs_0_1  nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# leaky_relu_16     leaky_relu()            (16, 32, 160, 160)         0            0
# sub_16            sub()                   (16, 32, 160, 160)         0            0
# up_3_1_convs_1_0  nn.Conv2d               (16, 32, 160, 160)      9248   7549747200
# up_3_1_convs_1_1  nn.BatchNorm2d          (16, 32, 160, 160)        64     26214400
# up_3_1_idconv_0   nn.Conv2d               (16, 32, 160, 160)      2080   1677721600
# add_11            add()                   (16, 32, 160, 160)         0            0
# leaky_relu_17     leaky_relu()            (16, 32, 160, 160)         0            0
# sub_17            sub()                   (16, 32, 160, 160)         0            0
# add_12            add()                   (16, 32, 160, 160)         0            0
# up_4_convs_0_0    nn.Conv2d               (16, 3, 160, 160)        867    707788800
# up_4_convs_0_1    nn.BatchNorm2d          (16, 3, 160, 160)          6      2457600
# leaky_relu_18     leaky_relu()            (16, 3, 160, 160)          0            0
# sub_18            sub()                   (16, 3, 160, 160)          0            0
# up_4_convs_1_0    nn.Conv2d               (16, 3, 160, 160)         84     66355200
# up_4_convs_1_1    nn.BatchNorm2d          (16, 3, 160, 160)          6      2457600
# up_4_idconv_0     nn.Conv2d               (16, 3, 160, 160)         99     78643200
# add_13            add()                   (16, 3, 160, 160)          0            0
# leaky_relu_19     leaky_relu()            (16, 3, 160, 160)          0            0
# sub_19            sub()                   (16, 3, 160, 160)          0            0
# add_14            add()                   (16, 3, 160, 160)          0            0
# end_convs_0_0     nn.Conv2d               (16, 3, 160, 160)         84     66355200
# end_convs_0_1     nn.BatchNorm2d          (16, 3, 160, 160)          6      2457600
# end_convs_0_2     nn.Identity             (16, 3, 160, 160)          0            0
# end_convs_1_0     nn.Conv2d               (16, 3, 160, 160)         84     66355200
# end_convs_1_1     nn.BatchNorm2d          (16, 3, 160, 160)          6      2457600
# add_15            add()                   (16, 3, 160, 160)          0            0
# end_act           nn.Identity             (16, 3, 160, 160)          0            0
# output            output                  (16, 3, 160, 160)          0            0

# %%
run_comparison('miniai_unet')
# Out:
# ===============================================================================================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #                   Mult-Adds                 Input Shape               Kernel Shape
# ===============================================================================================================================================================================
# TinyUnet                                           [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# ├─ResBlock: 1-1                                    [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    └─Sequential: 2-1                             [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    │    └─Sequential: 3-1                        [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    │    │    └─Conv2d: 4-1                       [16, 32, 160, 160]        896                       367,001,600               [16, 3, 160, 160]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-2                  [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    │    │    └─GeneralRelu: 4-3                  [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    └─Sequential: 3-2                        [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Conv2d: 4-4                       [16, 32, 160, 160]        9,248                     3,787,980,800             [16, 32, 160, 160]        [3, 3]
# │    │    │    └─BatchNorm2d: 4-5                  [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    └─Sequential: 2-2                             [16, 32, 160, 160]        --                        --                        [16, 3, 160, 160]         --
# │    │    └─Conv2d: 3-3                            [16, 32, 160, 160]        128                       52,428,800                [16, 3, 160, 160]         [1, 1]
# │    └─GeneralRelu: 2-3                            [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# ├─ModuleList: 1-2                                  --                        --                        --                        --                        --
# │    └─ResBlock: 2-4                               [16, 64, 80, 80]          --                        --                        [16, 32, 160, 160]        --
# │    │    └─Sequential: 3-4                        [16, 64, 80, 80]          --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Sequential: 4-6                   [16, 64, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    │    └─Conv2d: 5-1                  [16, 64, 160, 160]        18,496                    7,575,961,600             [16, 32, 160, 160]        [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-2             [16, 64, 160, 160]        128                       2,048                     [16, 64, 160, 160]        --
# │    │    │    │    └─GeneralRelu: 5-3             [16, 64, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    └─Sequential: 4-7                   [16, 64, 80, 80]          --                        --                        [16, 64, 160, 160]        --
# │    │    │    │    └─Conv2d: 5-4                  [16, 64, 80, 80]          36,928                    3,781,427,200             [16, 64, 160, 160]        [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-5             [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# │    │    └─AvgPool2d: 3-5                         [16, 32, 80, 80]          --                        --                        [16, 32, 160, 160]        2
# │    │    └─Sequential: 3-6                        [16, 64, 80, 80]          --                        --                        [16, 32, 80, 80]          --
# │    │    │    └─Conv2d: 4-8                       [16, 64, 80, 80]          2,112                     216,268,800               [16, 32, 80, 80]          [1, 1]
# │    │    └─GeneralRelu: 3-7                       [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# │    └─ResBlock: 2-5                               [16, 128, 40, 40]         --                        --                        [16, 64, 80, 80]          --
# │    │    └─Sequential: 3-8                        [16, 128, 40, 40]         --                        --                        [16, 64, 80, 80]          --
# │    │    │    └─Sequential: 4-9                   [16, 128, 80, 80]         --                        --                        [16, 64, 80, 80]          --
# │    │    │    │    └─Conv2d: 5-6                  [16, 128, 80, 80]         73,856                    7,562,854,400             [16, 64, 80, 80]          [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-7             [16, 128, 80, 80]         256                       4,096                     [16, 128, 80, 80]         --
# │    │    │    │    └─GeneralRelu: 5-8             [16, 128, 80, 80]         --                        --                        [16, 128, 80, 80]         --
# │    │    │    └─Sequential: 4-10                  [16, 128, 40, 40]         --                        --                        [16, 128, 80, 80]         --
# │    │    │    │    └─Conv2d: 5-9                  [16, 128, 40, 40]         147,584                   3,778,150,400             [16, 128, 80, 80]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-10            [16, 128, 40, 40]         256                       4,096                     [16, 128, 40, 40]         --
# │    │    └─AvgPool2d: 3-9                         [16, 64, 40, 40]          --                        --                        [16, 64, 80, 80]          2
# │    │    └─Sequential: 3-10                       [16, 128, 40, 40]         --                        --                        [16, 64, 40, 40]          --
# │    │    │    └─Conv2d: 4-11                      [16, 128, 40, 40]         8,320                     212,992,000               [16, 64, 40, 40]          [1, 1]
# │    │    └─GeneralRelu: 3-11                      [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    └─ResBlock: 2-6                               [16, 256, 20, 20]         --                        --                        [16, 128, 40, 40]         --
# │    │    └─Sequential: 3-12                       [16, 256, 20, 20]         --                        --                        [16, 128, 40, 40]         --
# │    │    │    └─Sequential: 4-12                  [16, 256, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    │    │    │    └─Conv2d: 5-11                 [16, 256, 40, 40]         295,168                   7,556,300,800             [16, 128, 40, 40]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-12            [16, 256, 40, 40]         512                       8,192                     [16, 256, 40, 40]         --
# │    │    │    │    └─GeneralRelu: 5-13            [16, 256, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    └─Sequential: 4-13                  [16, 256, 20, 20]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    │    └─Conv2d: 5-14                 [16, 256, 20, 20]         590,080                   3,776,512,000             [16, 256, 40, 40]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-15            [16, 256, 20, 20]         512                       8,192                     [16, 256, 20, 20]         --
# │    │    └─AvgPool2d: 3-13                        [16, 128, 20, 20]         --                        --                        [16, 128, 40, 40]         2
# │    │    └─Sequential: 3-14                       [16, 256, 20, 20]         --                        --                        [16, 128, 20, 20]         --
# │    │    │    └─Conv2d: 4-14                      [16, 256, 20, 20]         33,024                    211,353,600               [16, 128, 20, 20]         [1, 1]
# │    │    └─GeneralRelu: 3-15                      [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    └─ResBlock: 2-7                               [16, 512, 10, 10]         --                        --                        [16, 256, 20, 20]         --
# │    │    └─Sequential: 3-16                       [16, 512, 10, 10]         --                        --                        [16, 256, 20, 20]         --
# │    │    │    └─Sequential: 4-15                  [16, 512, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    │    │    │    └─Conv2d: 5-16                 [16, 512, 20, 20]         1,180,160                 7,553,024,000             [16, 256, 20, 20]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-17            [16, 512, 20, 20]         1,024                     16,384                    [16, 512, 20, 20]         --
# │    │    │    │    └─GeneralRelu: 5-18            [16, 512, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    └─Sequential: 4-16                  [16, 512, 10, 10]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    │    └─Conv2d: 5-19                 [16, 512, 10, 10]         2,359,808                 3,775,692,800             [16, 512, 20, 20]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-20            [16, 512, 10, 10]         1,024                     16,384                    [16, 512, 10, 10]         --
# │    │    └─AvgPool2d: 3-17                        [16, 256, 10, 10]         --                        --                        [16, 256, 20, 20]         2
# │    │    └─Sequential: 3-18                       [16, 512, 10, 10]         --                        --                        [16, 256, 10, 10]         --
# │    │    │    └─Conv2d: 4-17                      [16, 512, 10, 10]         131,584                   210,534,400               [16, 256, 10, 10]         [1, 1]
# │    │    └─GeneralRelu: 3-19                      [16, 512, 10, 10]         --                        --                        [16, 512, 10, 10]         --
# ├─ModuleList: 1-3                                  --                        --                        --                        --                        --
# │    └─Sequential: 2-8                             [16, 256, 20, 20]         --                        --                        [16, 512, 10, 10]         --
# │    │    └─UpsamplingNearest2d: 3-20              [16, 512, 20, 20]         --                        --                        [16, 512, 10, 10]         --
# │    │    └─ResBlock: 3-21                         [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    └─Sequential: 4-18                  [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    │    └─Sequential: 5-21             [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    │    │    └─Conv2d: 6-1             [16, 256, 20, 20]         1,179,904                 7,551,385,600             [16, 512, 20, 20]         [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-2        [16, 256, 20, 20]         512                       8,192                     [16, 256, 20, 20]         --
# │    │    │    │    │    └─GeneralRelu: 6-3        [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    │    │    │    └─Sequential: 5-22             [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    │    │    │    │    └─Conv2d: 6-4             [16, 256, 20, 20]         590,080                   3,776,512,000             [16, 256, 20, 20]         [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-5        [16, 256, 20, 20]         512                       8,192                     [16, 256, 20, 20]         --
# │    │    │    └─Sequential: 4-19                  [16, 256, 20, 20]         --                        --                        [16, 512, 20, 20]         --
# │    │    │    │    └─Conv2d: 5-23                 [16, 256, 20, 20]         131,328                   840,499,200               [16, 512, 20, 20]         [1, 1]
# │    │    │    └─GeneralRelu: 4-20                 [16, 256, 20, 20]         --                        --                        [16, 256, 20, 20]         --
# │    └─Sequential: 2-9                             [16, 128, 40, 40]         --                        --                        [16, 256, 20, 20]         --
# │    │    └─UpsamplingNearest2d: 3-22              [16, 256, 40, 40]         --                        --                        [16, 256, 20, 20]         --
# │    │    └─ResBlock: 3-23                         [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    └─Sequential: 4-21                  [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    │    └─Sequential: 5-24             [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    │    │    └─Conv2d: 6-6             [16, 128, 40, 40]         295,040                   7,553,024,000             [16, 256, 40, 40]         [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-7        [16, 128, 40, 40]         256                       4,096                     [16, 128, 40, 40]         --
# │    │    │    │    │    └─GeneralRelu: 6-8        [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    │    │    │    └─Sequential: 5-25             [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    │    │    │    │    └─Conv2d: 6-9             [16, 128, 40, 40]         147,584                   3,778,150,400             [16, 128, 40, 40]         [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-10       [16, 128, 40, 40]         256                       4,096                     [16, 128, 40, 40]         --
# │    │    │    └─Sequential: 4-22                  [16, 128, 40, 40]         --                        --                        [16, 256, 40, 40]         --
# │    │    │    │    └─Conv2d: 5-26                 [16, 128, 40, 40]         32,896                    842,137,600               [16, 256, 40, 40]         [1, 1]
# │    │    │    └─GeneralRelu: 4-23                 [16, 128, 40, 40]         --                        --                        [16, 128, 40, 40]         --
# │    └─Sequential: 2-10                            [16, 64, 80, 80]          --                        --                        [16, 128, 40, 40]         --
# │    │    └─UpsamplingNearest2d: 3-24              [16, 128, 80, 80]         --                        --                        [16, 128, 40, 40]         --
# │    │    └─ResBlock: 3-25                         [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    │    └─Sequential: 4-24                  [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    │    │    └─Sequential: 5-27             [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    │    │    │    └─Conv2d: 6-11            [16, 64, 80, 80]          73,792                    7,556,300,800             [16, 128, 80, 80]         [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-12       [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# │    │    │    │    │    └─GeneralRelu: 6-13       [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# │    │    │    │    └─Sequential: 5-28             [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# │    │    │    │    │    └─Conv2d: 6-14            [16, 64, 80, 80]          36,928                    3,781,427,200             [16, 64, 80, 80]          [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-15       [16, 64, 80, 80]          128                       2,048                     [16, 64, 80, 80]          --
# │    │    │    └─Sequential: 4-25                  [16, 64, 80, 80]          --                        --                        [16, 128, 80, 80]         --
# │    │    │    │    └─Conv2d: 5-29                 [16, 64, 80, 80]          8,256                     845,414,400               [16, 128, 80, 80]         [1, 1]
# │    │    │    └─GeneralRelu: 4-26                 [16, 64, 80, 80]          --                        --                        [16, 64, 80, 80]          --
# │    └─Sequential: 2-11                            [16, 32, 160, 160]        --                        --                        [16, 64, 80, 80]          --
# │    │    └─UpsamplingNearest2d: 3-26              [16, 64, 160, 160]        --                        --                        [16, 64, 80, 80]          --
# │    │    └─ResBlock: 3-27                         [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    └─Sequential: 4-27                  [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    │    └─Sequential: 5-30             [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    │    │    └─Conv2d: 6-16            [16, 32, 160, 160]        18,464                    7,562,854,400             [16, 64, 160, 160]        [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-17       [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    │    │    │    │    └─GeneralRelu: 6-18       [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    │    └─Sequential: 5-31             [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    │    │    │    │    └─Conv2d: 6-19            [16, 32, 160, 160]        9,248                     3,787,980,800             [16, 32, 160, 160]        [3, 3]
# │    │    │    │    │    └─BatchNorm2d: 6-20       [16, 32, 160, 160]        64                        1,024                     [16, 32, 160, 160]        --
# │    │    │    └─Sequential: 4-28                  [16, 32, 160, 160]        --                        --                        [16, 64, 160, 160]        --
# │    │    │    │    └─Conv2d: 5-32                 [16, 32, 160, 160]        2,080                     851,968,000               [16, 64, 160, 160]        [1, 1]
# │    │    │    └─GeneralRelu: 4-29                 [16, 32, 160, 160]        --                        --                        [16, 32, 160, 160]        --
# │    └─ResBlock: 2-12                              [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    │    └─Sequential: 3-28                       [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Sequential: 4-30                  [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    │    │    │    └─Conv2d: 5-33                 [16, 3, 160, 160]         867                       355,123,200               [16, 32, 160, 160]        [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-34            [16, 3, 160, 160]         6                         96                        [16, 3, 160, 160]         --
# │    │    │    │    └─GeneralRelu: 5-35            [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    │    └─Sequential: 4-31                  [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    │    │    └─Conv2d: 5-36                 [16, 3, 160, 160]         84                        34,406,400                [16, 3, 160, 160]         [3, 3]
# │    │    │    │    └─BatchNorm2d: 5-37            [16, 3, 160, 160]         6                         96                        [16, 3, 160, 160]         --
# │    │    └─Sequential: 3-29                       [16, 3, 160, 160]         --                        --                        [16, 32, 160, 160]        --
# │    │    │    └─Conv2d: 4-32                      [16, 3, 160, 160]         99                        40,550,400                [16, 32, 160, 160]        [1, 1]
# │    │    └─GeneralRelu: 3-30                      [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# ├─ResBlock: 1-4                                    [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    └─Sequential: 2-13                            [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    └─Sequential: 3-31                       [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    │    └─Conv2d: 4-33                      [16, 3, 160, 160]         84                        34,406,400                [16, 3, 160, 160]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-34                 [16, 3, 160, 160]         6                         96                        [16, 3, 160, 160]         --
# │    │    │    └─Identity: 4-35                    [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    └─Sequential: 3-32                       [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# │    │    │    └─Conv2d: 4-36                      [16, 3, 160, 160]         84                        34,406,400                [16, 3, 160, 160]         [3, 3]
# │    │    │    └─BatchNorm2d: 4-37                 [16, 3, 160, 160]         6                         96                        [16, 3, 160, 160]         --
# │    └─Identity: 2-14                              [16, 3, 160, 160]         --                        --                        [16, 3, 160, 160]         --
# ===============================================================================================================================================================================
# Total params: 7,420,122
# Trainable params: 7,420,122
# Non-trainable params: 0
# Total mult-adds (G): 99.65
# ===============================================================================================================================================================================
# Input size (MB): 4.92
# Forward/backward pass size (MB): 2677.15
# Params size (MB): 29.68
# Estimated Total Size (MB): 2711.74
# ===============================================================================================================================================================================
